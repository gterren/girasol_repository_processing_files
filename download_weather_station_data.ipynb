# %% [markdown]
# # Download data from any weather station in www.wunderground.com

# %%
# To do list:
# - Select Only the Necessary Comlumns
# - Transform time to unix times
# - Transform temperature in F. to celsius
# - Interpolar the data that is missing to 1 second resoluction
# - Check if any day in the girasol machine is not download yet
# - Either download it or remove them
# - Get Starting and ending data of the recording 2017_12_07-2019_01_18
# - Set code in functions
# - Make it rebust so it does not break in case of no existing data for a day
# - Lunch processing for all data

import csv
import requests
import time
import datetime

import numpy as np
import matplotlib.pylab as plt

from scipy import interpolate

# %%
# Define the url to request data from
def _get_url(weather_station_id, day, month, year):
    url = r'https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID={}&day={}&month={}&year={}&graphspan=day&format=1'
    return url.format(weather_station_id, day, month, year)

# Request content on the url
def _request_page_data(url):
    page = requests.get(url)
    return page.content.decode("utf-8") 

# Slip up data by rows
def _data_2_rows(data_):
    rows_ = []
    i = 0
    while True:
        ii = data_[i:].find(r'<br>')
        rows_.append(data_[i:i + ii])
        i = i + ii + 4
        if i > len(data_):
            break
    return rows_
# Temperature in F. to Celcius
def _celsius_2_fahrenheit(Temp):
    return (float(Temp) - 32.) * (5. / 9.)
# Presure in In. to mm.
def _inches_2_milimeters(In):
    return float(In) * 25.4
# Degrees to radinas
def _degrees_2_radias(Degree):
    return np.radians(float(Degree))
# Wind velocity in MPH to KPH
def _MPH_2_mps(MPH):
    return 1000. * float(MPH) * 1.609344 / 3600.
# Format columns to SI units and save it in a csv file
def _format_data(rows_, year, month, day):
    file_name = '{:04}_{:02}_{:02}.csv'.format(year, month, day)
    path = r'C:\Users\Guille\Desktop\weather_station\data\{}'.format(file_name)
    idx_ = [0, 1, 2, 3, 5, 6, 8]
    with open(path, "w", newline = '') as csv_file:
        writer = csv.writer(csv_file, delimiter = ',')
        for i in range(len(rows_) - 1):    
            cells_ = rows_[i].split(',')
            cells_ = [cells_[idx] for idx in idx_] 
            for ii in range(len(cells_)):
                # Return End of the line /n in string
                cells_[ii] = cells_[ii].lstrip()
                # Human Time to Unix 
                if ii == 0 and i > 0.: cells_[ii] = datetime.datetime.strptime(cells_[ii], '%Y-%m-%d %H:%M:%S').timestamp()
                # Temperature in F. to Celcius
                if ii == 1 and i > 0.: cells_[ii] = _celsius_2_fahrenheit(cells_[ii]) 
                # Dew Point in F. to Celcius
                if ii == 2 and i > 0.: cells_[ii] = _celsius_2_fahrenheit(cells_[ii]) 
                # Presure in In. to mm.
                if ii == 3 and i > 0.: cells_[ii] = _inches_2_milimeters(cells_[ii]) 
                # Degrees to radinas
                if ii == 4 and i > 0.: cells_[ii] = _degrees_2_radias(cells_[ii]) 
                # Wind velocity in MPH to KPH
                if ii == 5 and i > 0.: cells_[ii] = _MPH_2_mps(cells_[ii]) 
            if i > 0.: writer.writerow(cells_)
    return path

weather_station_id = r'KNMALBUQ11'  # West UNM Central Campus
weather_station_id = r'KNMALBUQ473' # UNM Hospital Helipad
#weather_station_id = r'KNMALBUQ118' # Airport Weather Station

for year in range(2017, 2018, 1):
    for month in range(12, 13, 1):
        for day in range(1, 32, 1):
            try:
                url = _get_url(weather_station_id, day, month, year)
                print(url)
                data_ = _request_page_data(url)
                rows_ = _data_2_rows(data_)
                path = _format_data(rows_, year, month, day)
            except:
                print(weather_station_id, day, month, year)
# Out:
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=1&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=2&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=3&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=4&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=5&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=6&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=7&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=8&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=9&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=10&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=11&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=12&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=13&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=14&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=15&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=16&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=17&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=18&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=19&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=20&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=21&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=22&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=23&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=24&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=25&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=26&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=27&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=28&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=29&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=30&month=12&year=2017&graphspan=day&format=1
# https://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=KNMALBUQ473&day=31&month=12&year=2017&graphspan=day&format=1

# %%
import os

# Interpolation
def _interpolate_csv_columns(X_, Y_):
    x_ = X_[:, 0]
    # Variables Initialization 
    #x_p_ = np.linspace(x_[0], x_[-1], num = int(x_[-1] - x_[0]) + 1, endpoint = True)
    x_p_ = Y_[:, 0]
    X_p_ = np.zeros((x_p_.shape[0], X_.shape[1]))
    X_p_[:, 0] = x_p_
    for idx in range(1, X_.shape[1]):
        y_ = X_[:, idx]
        _f = interpolate.interp1d(x_, y_)
        y_p_ = _f(x_p_)
        X_p_[:, idx] = y_p_
        #plt.figure(figsize = (20, 5))
        #plt.plot(x_p_, y_p_)
        #plt.plot(x_, y_, '.')
    return X_p_
# Load csv file
def _load_csv_file(path):
    return np.loadtxt(open(path, "rb"), delimiter = ",")
# Save it back to the csv file
def _save_csv_file(X_p_, path):
    return np.savetxt(path, X_p_, delimiter = ",")


path_iws = r'E:\weather_station'
path_opy = r'E:\girasol_repository_files\pyranometer'
path_ows = r'E:\girasol_repository_files\weather_station'

for file in os.listdir(path_py):
    file_ws = '{}\{}'.format(path_iws, file)
    file_py = '{}\{}'.format(path_opy, file)
    X_ = _load_csv_file(file_ws)
    Y_ = _load_csv_file(file_py)
    X_p_ = _interpolate_csv_columns(X_, Y_)
    print(X_.shape, X_p_.shape, Y_.shape)
    path = '{}\{}'.format(path_ows, file)
    _save_csv_file(X_p_, path)
    print(path)
# Out:
# (229, 7) (86689, 7) (86689, 2)
# E:\girasol_repository_files\weather_station\2017_12_07.csv
# (217, 7) (86483, 7) (86483, 2)
# E:\girasol_repository_files\weather_station\2017_12_08.csv
# (213, 7) (86311, 7) (86311, 2)
# E:\girasol_repository_files\weather_station\2017_12_09.csv
# (206, 7) (86143, 7) (86143, 2)
# E:\girasol_repository_files\weather_station\2017_12_10.csv
# (224, 7) (85951, 7) (85951, 2)
# E:\girasol_repository_files\weather_station\2017_12_11.csv
# (218, 7) (85850, 7) (85850, 2)
# E:\girasol_repository_files\weather_station\2017_12_12.csv
# (222, 7) (85712, 7) (85712, 2)
# E:\girasol_repository_files\weather_station\2017_12_13.csv
# (294, 7) (85473, 7) (85473, 2)
# E:\girasol_repository_files\weather_station\2017_12_15.csv
# (333, 7) (85372, 7) (85372, 2)
# E:\girasol_repository_files\weather_station\2017_12_16.csv
# (331, 7) (85348, 7) (85348, 2)
# E:\girasol_repository_files\weather_station\2017_12_17.csv
# (325, 7) (85270, 7) (85270, 2)
# E:\girasol_repository_files\weather_station\2017_12_18.csv
# (327, 7) (85245, 7) (85245, 2)
# E:\girasol_repository_files\weather_station\2017_12_19.csv
# (332, 7) (85217, 7) (85217, 2)
# E:\girasol_repository_files\weather_station\2017_12_20.csv
# (327, 7) (85228, 7) (85228, 2)
# E:\girasol_repository_files\weather_station\2017_12_21.csv
# (286, 7) (85189, 7) (85189, 2)
# E:\girasol_repository_files\weather_station\2017_12_22.csv
# (326, 7) (85221, 7) (85221, 2)
# E:\girasol_repository_files\weather_station\2017_12_23.csv
# (334, 7) (85372, 7) (85372, 2)
# E:\girasol_repository_files\weather_station\2017_12_25.csv
# (346, 7) (85451, 7) (85451, 2)
# E:\girasol_repository_files\weather_station\2017_12_26.csv
# (344, 7) (85527, 7) (85527, 2)
# E:\girasol_repository_files\weather_station\2017_12_27.csv
# (342, 7) (85620, 7) (85620, 2)
# E:\girasol_repository_files\weather_station\2017_12_28.csv
# (335, 7) (85743, 7) (85743, 2)
# E:\girasol_repository_files\weather_station\2017_12_29.csv
# (330, 7) (85869, 7) (85869, 2)
# E:\girasol_repository_files\weather_station\2017_12_30.csv
# (334, 7) (86015, 7) (86015, 2)
# E:\girasol_repository_files\weather_station\2017_12_31.csv
# (325, 7) (86112, 7) (86112, 2)
# E:\girasol_repository_files\weather_station\2018_01_01.csv
# (287, 7) (86325, 7) (86325, 2)
# E:\girasol_repository_files\weather_station\2018_01_02.csv
# (304, 7) (86505, 7) (86505, 2)
# E:\girasol_repository_files\weather_station\2018_01_03.csv
# (343, 7) (86726, 7) (86726, 2)
# E:\girasol_repository_files\weather_station\2018_01_04.csv
# (311, 7) (86946, 7) (86946, 2)
# E:\girasol_repository_files\weather_station\2018_01_05.csv
# (304, 7) (87180, 7) (87180, 2)
# E:\girasol_repository_files\weather_station\2018_01_06.csv
# (310, 7) (87409, 7) (87409, 2)
# E:\girasol_repository_files\weather_station\2018_01_07.csv
# (443, 7) (87659, 7) (87659, 2)
# E:\girasol_repository_files\weather_station\2018_01_08.csv
# (453, 7) (87951, 7) (87951, 2)
# E:\girasol_repository_files\weather_station\2018_01_09.csv
# (80, 7) (88199, 7) (88199, 2)
# E:\girasol_repository_files\weather_station\2018_01_10.csv
# (217, 7) (88483, 7) (88483, 2)
# E:\girasol_repository_files\weather_station\2018_01_11.csv
# (230, 7) (88814, 7) (88814, 2)
# E:\girasol_repository_files\weather_station\2018_01_12.csv
# (222, 7) (89127, 7) (89127, 2)
# E:\girasol_repository_files\weather_station\2018_01_13.csv
# (230, 7) (89467, 7) (89467, 2)
# E:\girasol_repository_files\weather_station\2018_01_14.csv
# (228, 7) (89777, 7) (89777, 2)
# E:\girasol_repository_files\weather_station\2018_01_15.csv
# (206, 7) (90081, 7) (90081, 2)
# E:\girasol_repository_files\weather_station\2018_01_16.csv
# (254, 7) (90465, 7) (90465, 2)
# E:\girasol_repository_files\weather_station\2018_01_17.csv
# (285, 7) (91278, 7) (91278, 2)
# E:\girasol_repository_files\weather_station\2018_01_19.csv
# (285, 7) (91667, 7) (91667, 2)
# E:\girasol_repository_files\weather_station\2018_01_20.csv
# (269, 7) (92020, 7) (92020, 2)
# E:\girasol_repository_files\weather_station\2018_01_21.csv
# (259, 7) (92428, 7) (92428, 2)
# E:\girasol_repository_files\weather_station\2018_01_22.csv
# (240, 7) (92860, 7) (92860, 2)
# E:\girasol_repository_files\weather_station\2018_01_23.csv
# (265, 7) (93317, 7) (93317, 2)
# E:\girasol_repository_files\weather_station\2018_01_24.csv
# (285, 7) (93742, 7) (93742, 2)
# E:\girasol_repository_files\weather_station\2018_01_25.csv
# (285, 7) (94205, 7) (94205, 2)
# E:\girasol_repository_files\weather_station\2018_01_26.csv
# (285, 7) (94644, 7) (94644, 2)
# E:\girasol_repository_files\weather_station\2018_01_27.csv
# (285, 7) (95111, 7) (95111, 2)
# E:\girasol_repository_files\weather_station\2018_01_28.csv
# (284, 7) (95586, 7) (95586, 2)
# E:\girasol_repository_files\weather_station\2018_01_29.csv
# (283, 7) (96022, 7) (96022, 2)
# E:\girasol_repository_files\weather_station\2018_01_30.csv
# (284, 7) (96553, 7) (96553, 2)
# E:\girasol_repository_files\weather_station\2018_01_31.csv
# (284, 7) (97060, 7) (97060, 2)
# E:\girasol_repository_files\weather_station\2018_02_01.csv
# (284, 7) (97518, 7) (97518, 2)
# E:\girasol_repository_files\weather_station\2018_02_02.csv
# (283, 7) (98023, 7) (98023, 2)
# E:\girasol_repository_files\weather_station\2018_02_03.csv
# (284, 7) (98512, 7) (98512, 2)
# E:\girasol_repository_files\weather_station\2018_02_04.csv
# (285, 7) (100036, 7) (100036, 2)
# E:\girasol_repository_files\weather_station\2018_02_07.csv
# (283, 7) (100511, 7) (100511, 2)
# E:\girasol_repository_files\weather_station\2018_02_08.csv
# (285, 7) (101510, 7) (101510, 2)
# E:\girasol_repository_files\weather_station\2018_02_10.csv
# (284, 7) (102039, 7) (102039, 2)
# E:\girasol_repository_files\weather_station\2018_02_11.csv
# (285, 7) (103119, 7) (103119, 2)
# E:\girasol_repository_files\weather_station\2018_02_13.csv
# (284, 7) (103586, 7) (103586, 2)
# E:\girasol_repository_files\weather_station\2018_02_14.csv
# (284, 7) (104135, 7) (104135, 2)
# E:\girasol_repository_files\weather_station\2018_02_15.csv
# (285, 7) (104677, 7) (104677, 2)
# E:\girasol_repository_files\weather_station\2018_02_16.csv
# (281, 7) (105329, 7) (105329, 2)
# E:\girasol_repository_files\weather_station\2018_02_17.csv
# (284, 7) (105804, 7) (105804, 2)
# E:\girasol_repository_files\weather_station\2018_02_18.csv
# (285, 7) (106359, 7) (106359, 2)
# E:\girasol_repository_files\weather_station\2018_02_19.csv
# (285, 7) (106785, 7) (106785, 2)
# E:\girasol_repository_files\weather_station\2018_02_20.csv
# (284, 7) (107418, 7) (107418, 2)
# E:\girasol_repository_files\weather_station\2018_02_21.csv
# (285, 7) (107914, 7) (107914, 2)
# E:\girasol_repository_files\weather_station\2018_02_22.csv
# (285, 7) (108490, 7) (108490, 2)
# E:\girasol_repository_files\weather_station\2018_02_23.csv
# (284, 7) (109020, 7) (109020, 2)
# E:\girasol_repository_files\weather_station\2018_02_24.csv
# (283, 7) (109541, 7) (109541, 2)
# E:\girasol_repository_files\weather_station\2018_02_25.csv
# (285, 7) (110138, 7) (110138, 2)
# E:\girasol_repository_files\weather_station\2018_02_26.csv
# (284, 7) (111775, 7) (111775, 2)
# E:\girasol_repository_files\weather_station\2018_03_01.csv
# (284, 7) (112351, 7) (112351, 2)
# E:\girasol_repository_files\weather_station\2018_03_02.csv
# (284, 7) (112937, 7) (112937, 2)
# E:\girasol_repository_files\weather_station\2018_03_03.csv
# (285, 7) (113452, 7) (113452, 2)
# E:\girasol_repository_files\weather_station\2018_03_04.csv
# (286, 7) (113917, 7) (113917, 2)
# E:\girasol_repository_files\weather_station\2018_03_05.csv
# (284, 7) (114498, 7) (114498, 2)
# E:\girasol_repository_files\weather_station\2018_03_06.csv
# (283, 7) (115034, 7) (115034, 2)
# E:\girasol_repository_files\weather_station\2018_03_07.csv
# (285, 7) (116186, 7) (116186, 2)
# E:\girasol_repository_files\weather_station\2018_03_09.csv
# (284, 7) (128543, 7) (128543, 2)
# E:\girasol_repository_files\weather_station\2018_04_02.csv
# (284, 7) (129027, 7) (129027, 2)
# E:\girasol_repository_files\weather_station\2018_04_03.csv
# (286, 7) (129531, 7) (129531, 2)
# E:\girasol_repository_files\weather_station\2018_04_04.csv
# (284, 7) (130024, 7) (130024, 2)
# E:\girasol_repository_files\weather_station\2018_04_05.csv
# (284, 7) (130500, 7) (130500, 2)
# E:\girasol_repository_files\weather_station\2018_04_06.csv
# (287, 7) (131044, 7) (131044, 2)
# E:\girasol_repository_files\weather_station\2018_04_07.csv
# (285, 7) (131412, 7) (131412, 2)
# E:\girasol_repository_files\weather_station\2018_04_08.csv
# (579, 7) (131872, 7) (131872, 2)
# E:\girasol_repository_files\weather_station\2018_04_09.csv
# (673, 7) (132346, 7) (132346, 2)
# E:\girasol_repository_files\weather_station\2018_04_10.csv
# (295, 7) (132819, 7) (132819, 2)
# E:\girasol_repository_files\weather_station\2018_04_11.csv
# (312, 7) (133216, 7) (133216, 2)
# E:\girasol_repository_files\weather_station\2018_04_12.csv
# (293, 7) (133444, 7) (133444, 2)
# E:\girasol_repository_files\weather_station\2018_04_13.csv
# (284, 7) (134562, 7) (134562, 2)
# E:\girasol_repository_files\weather_station\2018_04_15.csv
# (286, 7) (134898, 7) (134898, 2)
# E:\girasol_repository_files\weather_station\2018_04_16.csv
# (285, 7) (135821, 7) (135821, 2)
# E:\girasol_repository_files\weather_station\2018_04_18.csv
# (286, 7) (136202, 7) (136202, 2)
# E:\girasol_repository_files\weather_station\2018_04_19.csv
# (285, 7) (136554, 7) (136554, 2)
# E:\girasol_repository_files\weather_station\2018_04_20.csv
# (282, 7) (136984, 7) (136984, 2)
# E:\girasol_repository_files\weather_station\2018_04_21.csv
# (285, 7) (137506, 7) (137506, 2)
# E:\girasol_repository_files\weather_station\2018_04_22.csv
# (314, 7) (137915, 7) (137915, 2)
# E:\girasol_repository_files\weather_station\2018_04_23.csv
# (285, 7) (145107, 7) (145107, 2)
# E:\girasol_repository_files\weather_station\2018_05_14.csv
# (284, 7) (145491, 7) (145491, 2)
# E:\girasol_repository_files\weather_station\2018_05_15.csv
# (284, 7) (145731, 7) (145731, 2)
# E:\girasol_repository_files\weather_station\2018_05_16.csv
# (285, 7) (146081, 7) (146081, 2)
# E:\girasol_repository_files\weather_station\2018_05_17.csv
# (286, 7) (146257, 7) (146257, 2)
# E:\girasol_repository_files\weather_station\2018_05_18.csv
# (285, 7) (146533, 7) (146533, 2)
# E:\girasol_repository_files\weather_station\2018_05_19.csv
# (287, 7) (146753, 7) (146753, 2)
# E:\girasol_repository_files\weather_station\2018_05_20.csv
# (287, 7) (146852, 7) (146852, 2)
# E:\girasol_repository_files\weather_station\2018_05_21.csv
# (287, 7) (147232, 7) (147232, 2)
# E:\girasol_repository_files\weather_station\2018_05_22.csv
# (285, 7) (147476, 7) (147476, 2)
# E:\girasol_repository_files\weather_station\2018_05_23.csv
# (285, 7) (147696, 7) (147696, 2)
# E:\girasol_repository_files\weather_station\2018_05_24.csv
# (284, 7) (147959, 7) (147959, 2)
# E:\girasol_repository_files\weather_station\2018_05_26.csv
# (288, 7) (149940, 7) (149940, 2)
# E:\girasol_repository_files\weather_station\2018_06_06.csv
# (288, 7) (150130, 7) (150130, 2)
# E:\girasol_repository_files\weather_station\2018_06_07.csv
# (305, 7) (150249, 7) (150249, 2)
# E:\girasol_repository_files\weather_station\2018_06_08.csv
# (288, 7) (150326, 7) (150326, 2)
# E:\girasol_repository_files\weather_station\2018_06_09.csv
# (288, 7) (150414, 7) (150414, 2)
# E:\girasol_repository_files\weather_station\2018_06_10.csv
# (288, 7) (150456, 7) (150456, 2)
# E:\girasol_repository_files\weather_station\2018_06_11.csv
# (288, 7) (150532, 7) (150532, 2)
# E:\girasol_repository_files\weather_station\2018_06_12.csv
# (288, 7) (150542, 7) (150542, 2)
# E:\girasol_repository_files\weather_station\2018_06_13.csv
# (288, 7) (150617, 7) (150617, 2)
# E:\girasol_repository_files\weather_station\2018_06_14.csv
# (288, 7) (150684, 7) (150684, 2)
# E:\girasol_repository_files\weather_station\2018_06_15.csv
# (288, 7) (150945, 7) (150945, 2)
# E:\girasol_repository_files\weather_station\2018_06_22.csv
# (288, 7) (150922, 7) (150922, 2)
# E:\girasol_repository_files\weather_station\2018_06_23.csv
# (288, 7) (150884, 7) (150884, 2)
# E:\girasol_repository_files\weather_station\2018_06_24.csv
# (288, 7) (150857, 7) (150857, 2)
# E:\girasol_repository_files\weather_station\2018_06_25.csv
# (288, 7) (150546, 7) (150546, 2)
# E:\girasol_repository_files\weather_station\2018_06_30.csv
# (288, 7) (150631, 7) (150631, 2)
# E:\girasol_repository_files\weather_station\2018_07_01.csv
# (288, 7) (150489, 7) (150489, 2)
# E:\girasol_repository_files\weather_station\2018_07_02.csv
# (288, 7) (150150, 7) (150150, 2)
# E:\girasol_repository_files\weather_station\2018_07_04.csv
# (288, 7) (149738, 7) (149738, 2)
# E:\girasol_repository_files\weather_station\2018_07_08.csv
# (288, 7) (149580, 7) (149580, 2)
# E:\girasol_repository_files\weather_station\2018_07_09.csv
# (288, 7) (149543, 7) (149543, 2)
# E:\girasol_repository_files\weather_station\2018_07_10.csv
# (288, 7) (149372, 7) (149372, 2)
# E:\girasol_repository_files\weather_station\2018_07_11.csv
# (290, 7) (149205, 7) (149205, 2)
# E:\girasol_repository_files\weather_station\2018_07_12.csv
# (288, 7) (148995, 7) (148995, 2)
# E:\girasol_repository_files\weather_station\2018_07_13.csv
# (288, 7) (148932, 7) (148932, 2)
# E:\girasol_repository_files\weather_station\2018_07_14.csv
# (288, 7) (148722, 7) (148722, 2)
# E:\girasol_repository_files\weather_station\2018_07_15.csv
# (288, 7) (148122, 7) (148122, 2)
# E:\girasol_repository_files\weather_station\2018_07_18.csv
# (289, 7) (147858, 7) (147858, 2)
# E:\girasol_repository_files\weather_station\2018_07_19.csv
# (288, 7) (147792, 7) (147792, 2)
# E:\girasol_repository_files\weather_station\2018_07_20.csv
# (288, 7) (147557, 7) (147557, 2)
# E:\girasol_repository_files\weather_station\2018_07_21.csv
# (288, 7) (147264, 7) (147264, 2)
# E:\girasol_repository_files\weather_station\2018_07_22.csv
# (288, 7) (146782, 7) (146782, 2)
# E:\girasol_repository_files\weather_station\2018_07_24.csv
# (288, 7) (146511, 7) (146511, 2)
# E:\girasol_repository_files\weather_station\2018_07_25.csv
# (288, 7) (141831, 7) (141831, 2)
# E:\girasol_repository_files\weather_station\2018_08_09.csv
# (288, 7) (136683, 7) (136683, 2)
# E:\girasol_repository_files\weather_station\2018_08_22.csv
# (288, 7) (136463, 7) (136463, 2)
# E:\girasol_repository_files\weather_station\2018_08_23.csv
# (288, 7) (135948, 7) (135948, 2)
# E:\girasol_repository_files\weather_station\2018_08_24.csv
# (288, 7) (135595, 7) (135595, 2)
# E:\girasol_repository_files\weather_station\2018_08_25.csv
# (288, 7) (135171, 7) (135171, 2)
# E:\girasol_repository_files\weather_station\2018_08_26.csv
# (288, 7) (134702, 7) (134702, 2)
# E:\girasol_repository_files\weather_station\2018_08_27.csv
# (288, 7) (134300, 7) (134300, 2)
# E:\girasol_repository_files\weather_station\2018_08_28.csv
# (288, 7) (133866, 7) (133866, 2)
# E:\girasol_repository_files\weather_station\2018_08_29.csv
# (288, 7) (133375, 7) (133375, 2)
# E:\girasol_repository_files\weather_station\2018_08_30.csv
# (288, 7) (132378, 7) (132378, 2)
# E:\girasol_repository_files\weather_station\2018_09_01.csv
# (288, 7) (132006, 7) (132006, 2)
# E:\girasol_repository_files\weather_station\2018_09_02.csv
# (288, 7) (131549, 7) (131549, 2)
# E:\girasol_repository_files\weather_station\2018_09_03.csv
# (288, 7) (131137, 7) (131137, 2)
# E:\girasol_repository_files\weather_station\2018_09_04.csv
# (288, 7) (130783, 7) (130783, 2)
# E:\girasol_repository_files\weather_station\2018_09_05.csv
# (288, 7) (127477, 7) (127477, 2)
# E:\girasol_repository_files\weather_station\2018_09_12.csv
# (288, 7) (126966, 7) (126966, 2)
# E:\girasol_repository_files\weather_station\2018_09_13.csv
# (288, 7) (126470, 7) (126470, 2)
# E:\girasol_repository_files\weather_station\2018_09_14.csv
# (288, 7) (125972, 7) (125972, 2)
# E:\girasol_repository_files\weather_station\2018_09_15.csv
# (288, 7) (125462, 7) (125462, 2)
# E:\girasol_repository_files\weather_station\2018_09_16.csv
# (288, 7) (125036, 7) (125036, 2)
# E:\girasol_repository_files\weather_station\2018_09_17.csv
# (288, 7) (124478, 7) (124478, 2)
# E:\girasol_repository_files\weather_station\2018_09_18.csv
# (288, 7) (123961, 7) (123961, 2)
# E:\girasol_repository_files\weather_station\2018_09_19.csv
# (288, 7) (123332, 7) (123332, 2)
# E:\girasol_repository_files\weather_station\2018_09_20.csv
# (288, 7) (122902, 7) (122902, 2)
# E:\girasol_repository_files\weather_station\2018_09_21.csv
# (288, 7) (122383, 7) (122383, 2)
# E:\girasol_repository_files\weather_station\2018_09_22.csv
# (288, 7) (121892, 7) (121892, 2)
# E:\girasol_repository_files\weather_station\2018_09_23.csv
# (288, 7) (113404, 7) (113404, 2)
# E:\girasol_repository_files\weather_station\2018_10_09.csv
# (288, 7) (112933, 7) (112933, 2)
# E:\girasol_repository_files\weather_station\2018_10_10.csv
# (288, 7) (112351, 7) (112351, 2)
# E:\girasol_repository_files\weather_station\2018_10_11.csv
# (288, 7) (111855, 7) (111855, 2)
# E:\girasol_repository_files\weather_station\2018_10_12.csv
# (288, 7) (111265, 7) (111265, 2)
# E:\girasol_repository_files\weather_station\2018_10_13.csv
# (288, 7) (110693, 7) (110693, 2)
# E:\girasol_repository_files\weather_station\2018_10_14.csv
# (288, 7) (110075, 7) (110075, 2)
# E:\girasol_repository_files\weather_station\2018_10_15.csv
# (288, 7) (109556, 7) (109556, 2)
# E:\girasol_repository_files\weather_station\2018_10_16.csv
# (283, 7) (109100, 7) (109100, 2)
# E:\girasol_repository_files\weather_station\2018_10_17.csv
# (288, 7) (108407, 7) (108407, 2)
# E:\girasol_repository_files\weather_station\2018_10_18.csv
# (288, 7) (108063, 7) (108063, 2)
# E:\girasol_repository_files\weather_station\2018_10_19.csv
# (288, 7) (106906, 7) (106906, 2)
# E:\girasol_repository_files\weather_station\2018_10_21.csv
# (289, 7) (106346, 7) (106346, 2)
# E:\girasol_repository_files\weather_station\2018_10_22.csv
# (288, 7) (105710, 7) (105710, 2)
# E:\girasol_repository_files\weather_station\2018_10_23.csv
# (288, 7) (100511, 7) (100511, 2)
# E:\girasol_repository_files\weather_station\2018_11_02.csv
# (288, 7) (100008, 7) (100008, 2)
# E:\girasol_repository_files\weather_station\2018_11_03.csv
# (300, 7) (99468, 7) (99468, 2)
# E:\girasol_repository_files\weather_station\2018_11_04.csv
# (288, 7) (98989, 7) (98989, 2)
# E:\girasol_repository_files\weather_station\2018_11_05.csv
# (288, 7) (98483, 7) (98483, 2)
# E:\girasol_repository_files\weather_station\2018_11_06.csv
# (288, 7) (97983, 7) (97983, 2)
# E:\girasol_repository_files\weather_station\2018_11_07.csv
# (288, 7) (97452, 7) (97452, 2)
# E:\girasol_repository_files\weather_station\2018_11_08.csv
# (288, 7) (94130, 7) (94130, 2)
# E:\girasol_repository_files\weather_station\2018_11_15.csv
# (288, 7) (93700, 7) (93700, 2)
# E:\girasol_repository_files\weather_station\2018_11_16.csv
# (288, 7) (93301, 7) (93301, 2)
# E:\girasol_repository_files\weather_station\2018_11_17.csv
# (288, 7) (92833, 7) (92833, 2)
# E:\girasol_repository_files\weather_station\2018_11_18.csv
# (288, 7) (91220, 7) (91220, 2)
# E:\girasol_repository_files\weather_station\2018_11_22.csv
# (288, 7) (90900, 7) (90900, 2)
# E:\girasol_repository_files\weather_station\2018_11_23.csv
# (288, 7) (90478, 7) (90478, 2)
# E:\girasol_repository_files\weather_station\2018_11_24.csv
# (288, 7) (89402, 7) (89402, 2)
# E:\girasol_repository_files\weather_station\2018_11_27.csv
# (288, 7) (89098, 7) (89098, 2)
# E:\girasol_repository_files\weather_station\2018_11_28.csv
# (288, 7) (88566, 7) (88566, 2)
# E:\girasol_repository_files\weather_station\2018_11_30.csv
# (288, 7) (88217, 7) (88217, 2)
# E:\girasol_repository_files\weather_station\2018_12_01.csv
# (288, 7) (87904, 7) (87904, 2)
# E:\girasol_repository_files\weather_station\2018_12_02.csv
# (288, 7) (87614, 7) (87614, 2)
# E:\girasol_repository_files\weather_station\2018_12_03.csv
# (288, 7) (87342, 7) (87342, 2)
# E:\girasol_repository_files\weather_station\2018_12_04.csv
# (288, 7) (86757, 7) (86757, 2)
# E:\girasol_repository_files\weather_station\2018_12_07.csv
# (288, 7) (86198, 7) (86198, 2)
# E:\girasol_repository_files\weather_station\2018_12_09.csv
# (288, 7) (85880, 7) (85880, 2)
# E:\girasol_repository_files\weather_station\2018_12_10.csv
# (288, 7) (85966, 7) (85966, 2)
# E:\girasol_repository_files\weather_station\2018_12_11.csv
# (288, 7) (85880, 7) (85880, 2)
# E:\girasol_repository_files\weather_station\2018_12_12.csv
# (288, 7) (85697, 7) (85697, 2)
# E:\girasol_repository_files\weather_station\2018_12_13.csv
# (288, 7) (85472, 7) (85472, 2)
# E:\girasol_repository_files\weather_station\2018_12_15.csv
# (288, 7) (85461, 7) (85461, 2)
# E:\girasol_repository_files\weather_station\2018_12_16.csv
# (288, 7) (85368, 7) (85368, 2)
# E:\girasol_repository_files\weather_station\2018_12_17.csv
# (288, 7) (85382, 7) (85382, 2)
# E:\girasol_repository_files\weather_station\2018_12_18.csv
# (288, 7) (85263, 7) (85263, 2)
# E:\girasol_repository_files\weather_station\2018_12_19.csv
# (288, 7) (85236, 7) (85236, 2)
# E:\girasol_repository_files\weather_station\2018_12_20.csv
# (288, 7) (85229, 7) (85229, 2)
# E:\girasol_repository_files\weather_station\2018_12_21.csv
# (288, 7) (85256, 7) (85256, 2)
# E:\girasol_repository_files\weather_station\2018_12_22.csv
# (288, 7) (85231, 7) (85231, 2)
# E:\girasol_repository_files\weather_station\2018_12_23.csv
# (288, 7) (85288, 7) (85288, 2)
# E:\girasol_repository_files\weather_station\2018_12_24.csv
# (288, 7) (85368, 7) (85368, 2)
# E:\girasol_repository_files\weather_station\2018_12_25.csv
# (288, 7) (85467, 7) (85467, 2)
# E:\girasol_repository_files\weather_station\2018_12_26.csv
# (288, 7) (85540, 7) (85540, 2)
# E:\girasol_repository_files\weather_station\2018_12_27.csv
# (288, 7) (87625, 7) (87625, 2)
# E:\girasol_repository_files\weather_station\2019_01_08.csv
# (288, 7) (87904, 7) (87904, 2)
# E:\girasol_repository_files\weather_station\2019_01_09.csv
# (288, 7) (88220, 7) (88220, 2)
# E:\girasol_repository_files\weather_station\2019_01_10.csv
# (288, 7) (88576, 7) (88576, 2)
# E:\girasol_repository_files\weather_station\2019_01_11.csv
# (288, 7) (88843, 7) (88843, 2)
# E:\girasol_repository_files\weather_station\2019_01_12.csv
# (288, 7) (89116, 7) (89116, 2)
# E:\girasol_repository_files\weather_station\2019_01_13.csv
# (288, 7) (89519, 7) (89519, 2)
# E:\girasol_repository_files\weather_station\2019_01_14.csv
# (288, 7) (89836, 7) (89836, 2)
# E:\girasol_repository_files\weather_station\2019_01_15.csv
# (288, 7) (90204, 7) (90204, 2)
# E:\girasol_repository_files\weather_station\2019_01_16.csv
# (288, 7) (90524, 7) (90524, 2)
# E:\girasol_repository_files\weather_station\2019_01_17.csv
# (288, 7) (90878, 7) (90878, 2)
# E:\girasol_repository_files\weather_station\2019_01_18.csv
# (288, 7) (91244, 7) (91244, 2)
# E:\girasol_repository_files\weather_station\2019_01_19.csv
# (288, 7) (91666, 7) (91666, 2)
# E:\girasol_repository_files\weather_station\2019_01_20.csv
# (288, 7) (1616, 7) (1616, 2)
# E:\girasol_repository_files\weather_station\2019_02_14.csv
# (288, 7) (1814, 7) (1814, 2)
# E:\girasol_repository_files\weather_station\2019_02_15.csv
